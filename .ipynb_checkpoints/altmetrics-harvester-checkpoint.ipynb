# %%
import os
import json
import requests
import pandas as pd
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'altmetrics-harvester.ipynb',
#  'last_quarter.csv',
#  'last_quarter.json',
#  'one_year.csv',
#  'one_year.json',
#  'README.md']

# %%
d = json.loads(requests.get('https://api.altmetric.com/v1/citations/1y?doi_prefix=10.5519').text)
del d['query']
with open('one_year.json', 'w') as data_file:
    data = json.dump(d, data_file)

# %%
df1 = pd.read_json('one_year.json')
df1
# Out:
#                                               results
# 0   {'title': 'The 2016 release of the PREDICTS da...
# 1   {'title': 'iCollections', 'doi': '10.5519/0038...
# 2   {'title': 'Collection specimens', 'doi': '10.5...
# 3   {'title': 'Insect Pollinators Initiative', 'do...
# 4   {'title': 'Mark My Bird', 'doi': '10.5519/0025...
# 5   {'title': 'Sloane Herbarium', 'doi': '10.5519/...
# 6   {'title': 'Ludlow Museum Fossils in Shropshire...
# 7   {'title': 'Phthiraptera collection', 'doi': '1...
# 8   {'title': 'Mark My Bird', 'doi': '10.5519/0005...
# 9   {'title': 'NHM Interactions Bank', 'doi': '10....
# 10  {'title': 'Clayton Herbarium', 'doi': '10.5519...

# %%
results = pd.read_json( (df1['results']).to_json(), orient='index')
images = pd.read_json( (results['images']).to_json(), orient='index')
full_results = pd.concat([results, images], axis=1, join_axes=[results.index])
full_results
# Out:
#       added_on  altmetric_id  \
# 0   1484945804      15616163
# 1   1490001929      17827714
# 10  1485265758      15737317
# 2   1485265780      15737327
# 3   1490970197      18352776
# 4   1486632170      16252778
# 5   1504187631      24571670
# 6   1494602749      20076644
# 7   1503749404      24347051
# 8   1486484774      16203308
# 9   1488820840      17055870
#
#                                               authors  \
# 0   [Lawrence N Hudson; Tim Newbold; Sara Contu; S...
# 1   [Gordon L J Paterson; Sara Albuquerque; Vladim...
# 10                                   [Charlie Jarvis]
# 2                            [Natural History Museum]
# 3   [Professor Graham N Stone, Professor Alfried V...
# 4   [Gavin H. Thomas (University of Sheffield & Na...
# 5                                    [Charlie Jarvis]
# 6                    [Daniel Lockett, Jackie Tweddle]
# 7   [Olha Schedrina, Louise Allan, Paul Brown, Lau...
# 8   [Gavin H. Thomas (University of Sheffield & Na...
# 9   [Ed Baker; Ian J. Kitching; George W. Beccalon...
#
#     cited_by_accounts_count  cited_by_feeds_count  cited_by_msm_count  \
# 0                       159                   1.0                 NaN
# 1                        65                   NaN                 NaN
# 10                        1                   NaN                 NaN
# 2                        21                   NaN                 1.0
# 3                        13                   1.0                 NaN
# 4                        16                   NaN                 NaN
# 5                         2                   1.0                 NaN
# 6                        10                   NaN                 NaN
# 7                         3                   NaN                 NaN
# 8                         4                   NaN                 NaN
# 9                         2                   NaN                 NaN
#
#     cited_by_posts_count  cited_by_tweeters_count  \
# 0                    197                      158
# 1                     74                       65
# 10                     1                        1
# 2                     21                       20
# 3                     18                       12
# 4                     16                       16
# 5                      2                        1
# 6                     10                       10
# 7                      3                        3
# 8                      4                        4
# 9                      2                        2
#
#                               cohorts  \
# 0   {'pub': 105, 'sci': 49, 'com': 4}
# 1    {'sci': 13, 'pub': 50, 'com': 2}
# 10                         {'sci': 1}
# 2     {'pub': 17, 'sci': 1, 'com': 2}
# 3                         {'pub': 12}
# 4               {'pub': 13, 'sci': 3}
# 5                          {'pub': 1}
# 6                {'pub': 8, 'sci': 2}
# 7                          {'pub': 3}
# 8                {'pub': 3, 'sci': 1}
# 9                          {'pub': 2}
#
#                                           details_url  \
# 0   http://www.altmetric.com/details.php?citation_...
# 1   http://www.altmetric.com/details.php?citation_...
# 10  http://www.altmetric.com/details.php?citation_...
# 2   http://www.altmetric.com/details.php?citation_...
# 3   http://www.altmetric.com/details.php?citation_...
# 4   http://www.altmetric.com/details.php?citation_...
# 5   http://www.altmetric.com/details.php?citation_...
# 6   http://www.altmetric.com/details.php?citation_...
# 7   http://www.altmetric.com/details.php?citation_...
# 8   http://www.altmetric.com/details.php?citation_...
# 9   http://www.altmetric.com/details.php?citation_...
#
#                           ...                         readers_count schema  \
# 0                         ...                                     1  1.5.4
# 1                         ...                                     0  1.5.4
# 10                        ...                                     0  1.5.4
# 2                         ...                                     1  1.5.4
# 3                         ...                                     0  1.5.4
# 4                         ...                                     0  1.5.4
# 5                         ...                                     0  1.5.4
# 6                         ...                                     0  1.5.4
# 7                         ...                                     0  1.5.4
# 8                         ...                                     0  1.5.4
# 9                         ...                                     0  1.5.4
#
#       score                                             title  \
# 0   112.942         The 2016 release of the PREDICTS database
# 1    48.000                                      iCollections
# 10    1.000                                 Clayton Herbarium
# 2    25.250                              Collection specimens
# 3    14.730                     Insect Pollinators Initiative
# 4    11.200                                      Mark My Bird
# 5     8.080                                  Sloane Herbarium
# 6     7.950  Ludlow Museum Fossils in Shropshire Project data
# 7     2.500                           Phthiraptera collection
# 8     2.000                                      Mark My Bird
# 9     1.850                             NHM Interactions Bank
#
#                                                    tq     type  \
# 0   [#PREDICTS global #biodiversity #database proj...  article
# 1   [We provide #OpenAcess to our digitised UK Iri...  article
# 10                                                NaN  article
# 2   [Starting #advent with an illustration from Hi...  article
# 3   [The #IPIArchive data is available via #openac...  article
# 4   [The mark my bird dataset is now on the data p...  article
# 5                                                 NaN  article
# 6                                                 NaN  article
# 7                                                 NaN  article
# 8                     [Plus all the data open to all]  article
# 9                                                 NaN  article
#
#                                   url  \
# 0   http://dx.doi.org/10.5519/0066354
# 1   http://dx.doi.org/10.5519/0038559
# 10  http://dx.doi.org/10.5519/0063794
# 2   http://dx.doi.org/10.5519/0002965
# 3   http://dx.doi.org/10.5519/0062900
# 4   http://dx.doi.org/10.5519/0025663
# 5   http://dx.doi.org/10.5519/0081520
# 6   http://dx.doi.org/10.5519/0015223
# 7   http://dx.doi.org/10.5519/0096731
# 8   http://dx.doi.org/10.5519/0005413
# 9   http://dx.doi.org/10.5519/0060767
#
#                                                 large  \
# 0   https://badges.altmetric.com/?size=180&score=1...
# 1   https://badges.altmetric.com/?size=180&score=4...
# 10  https://badges.altmetric.com/?size=180&score=1...
# 2   https://badges.altmetric.com/?size=180&score=2...
# 3   https://badges.altmetric.com/?size=180&score=1...
# 4   https://badges.altmetric.com/?size=180&score=1...
# 5   https://badges.altmetric.com/?size=180&score=9...
# 6   https://badges.altmetric.com/?size=180&score=8...
# 7   https://badges.altmetric.com/?size=180&score=3...
# 8   https://badges.altmetric.com/?size=180&score=2...
# 9   https://badges.altmetric.com/?size=180&score=2...
#
#                                                medium  \
# 0   https://badges.altmetric.com/?size=100&score=1...
# 1   https://badges.altmetric.com/?size=100&score=4...
# 10  https://badges.altmetric.com/?size=100&score=1...
# 2   https://badges.altmetric.com/?size=100&score=2...
# 3   https://badges.altmetric.com/?size=100&score=1...
# 4   https://badges.altmetric.com/?size=100&score=1...
# 5   https://badges.altmetric.com/?size=100&score=9...
# 6   https://badges.altmetric.com/?size=100&score=8...
# 7   https://badges.altmetric.com/?size=100&score=3...
# 8   https://badges.altmetric.com/?size=100&score=2...
# 9   https://badges.altmetric.com/?size=100&score=2...
#
#                                                 small
# 0   https://badges.altmetric.com/?size=64&score=11...
# 1   https://badges.altmetric.com/?size=64&score=48...
# 10  https://badges.altmetric.com/?size=64&score=1&...
# 2   https://badges.altmetric.com/?size=64&score=26...
# 3   https://badges.altmetric.com/?size=64&score=15...
# 4   https://badges.altmetric.com/?size=64&score=12...
# 5   https://badges.altmetric.com/?size=64&score=9&...
# 6   https://badges.altmetric.com/?size=64&score=8&...
# 7   https://badges.altmetric.com/?size=64&score=3&...
# 8   https://badges.altmetric.com/?size=64&score=2&...
# 9   https://badges.altmetric.com/?size=64&score=2&...
#
# [11 rows x 27 columns]

# %%
full_results.to_csv('one_year.csv')
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'altmetrics-harvester.ipynb',
#  'last_quarter.csv',
#  'last_quarter.json',
#  'one_year.csv',
#  'one_year.json',
#  'README.md']
